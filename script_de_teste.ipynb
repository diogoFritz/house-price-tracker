# %%
from utils import json_to_table, table_to_csv

# %%
df = json_to_table("schema_apartamento.json")
df
# Out:
#    id id_anuncio                                               link  \
# 0   1       None  https://casa.sapo.pt/comprar-apartamento-t1-li...
#
#      tipo_casa   preco  preco_metro tipologia distrito concelho    freguesia  \
# 0  Apartamento  350000      8139.53        T1   Lisboa   Lisboa  São Vicente
#
#    ano_construcao estado  area_util  area_bruta
# 0            2022  usado         43          51
